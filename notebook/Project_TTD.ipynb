# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# cleaning.ipynb
# exploring.ipynb
# Replacing null values with UN
# Checking for NaN values

# %% [markdown]
# # Traveler Trip Dataset
# https://www.kaggle.com/datasets/rkiattisak/traveler-trip-data

# %%
# -- Showing DataSet -- #
file1 = pd.read_csv("../data/raw/travel_dataset.csv")
file1
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)
# 0          1              London, UK   5/1/2023   5/8/2023              7.0  \
# 1          2        Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2          3         Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3          4           New York, USA  8/15/2023  8/29/2023             14.0
# 4          5            Tokyo, Japan  9/10/2023  9/17/2023              7.0
# ..       ...                     ...        ...        ...              ...
# 134      135  Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136       Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137       Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# 137      138        Barcelona, Spain  9/15/2023  9/22/2023              7.0
# 138      139   Auckland, New Zealand  10/1/2023  10/8/2023              7.0
#
#        Traveler name  Traveler age Traveler gender Traveler nationality
# 0         John Smith          35.0            Male             American  \
# 1           Jane Doe          28.0          Female             Canadian
# 2          David Lee          45.0            Male               Korean
# 3      Sarah Johnson          29.0          Female              British
# 4         Kim Nguyen          26.0          Female           Vietnamese
# ..               ...           ...             ...                  ...
# 134       Jose Perez          37.0            Male            Brazilian
# 135      Emma Wilson          29.0          Female             Canadian
# 136        Ryan Chen          34.0            Male              Chinese
# 137  Sofia Rodriguez          25.0          Female              Spanish
# 138    William Brown          39.0            Male        New Zealander
#
#     Accommodation type Accommodation cost Transportation type
# 0                Hotel               1200              Flight  \
# 1               Resort                800              Flight
# 2                Villa               1000              Flight
# 3                Hotel               2000              Flight
# 4               Airbnb                700               Train
# ..                 ...                ...                 ...
# 134             Hostel               2500                 Car
# 135              Hotel               5000            Airplane
# 136             Hostel               2000               Train
# 137             Airbnb               6000            Airplane
# 138              Hotel               7000               Train
#
#     Transportation cost
# 0                   600
# 1                   500
# 2                   700
# 3                  1000
# 4                   200
# ..                  ...
# 134                2000
# 135                3000
# 136                1000
# 137                2500
# 138                2500
#
# [139 rows x 13 columns]

# %%
# -- Showing DataFrame Shape -- #
display(file1.shape)
# Out:
# (139, 13)

# %%
# -- Showing DataFrame Info -- #
display(file1.dtypes)
# Out:
# Trip ID                   int64
# Destination              object
# Start date               object
# End date                 object
# Duration (days)         float64
# Traveler name            object
# Traveler age            float64
# Traveler gender          object
# Traveler nationality     object
# Accommodation type       object
# Accommodation cost       object
# Transportation type      object
# Transportation cost      object
# dtype: object

# %%
# -- Showing DataFrame Columns -- #
display(file1.columns)
# Out:
# Index(['Trip ID', 'Destination', 'Start date', 'End date', 'Duration (days)',
#        'Traveler name', 'Traveler age', 'Traveler gender',
#        'Traveler nationality', 'Accommodation type', 'Accommodation cost',
#        'Transportation type', 'Transportation cost'],
#       dtype='object')

# %%
# -- Standardizing Column Names -- #
cols = []
for col in file1.columns:
    col = col.lower().replace(' ', '_')
    cols.append(col)
file1.columns = cols
file1.head()
# Out:
#    trip_id       destination start_date   end_date  duration_(days)
# 0        1        London, UK   5/1/2023   5/8/2023              7.0  \
# 1        2  Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2        3   Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3        4     New York, USA  8/15/2023  8/29/2023             14.0
# 4        5      Tokyo, Japan  9/10/2023  9/17/2023              7.0
#
#    traveler_name  traveler_age traveler_gender traveler_nationality
# 0     John Smith          35.0            Male             American  \
# 1       Jane Doe          28.0          Female             Canadian
# 2      David Lee          45.0            Male               Korean
# 3  Sarah Johnson          29.0          Female              British
# 4     Kim Nguyen          26.0          Female           Vietnamese
#
#   accommodation_type accommodation_cost transportation_type
# 0              Hotel               1200              Flight  \
# 1             Resort                800              Flight
# 2              Villa               1000              Flight
# 3              Hotel               2000              Flight
# 4             Airbnb                700               Train
#
#   transportation_cost
# 0                 600
# 1                 500
# 2                 700
# 3                1000
# 4                 200

# %%
# -- Checking Null values -- #

file1.isna().sum()
# Out:
# trip_id                 0
# destination             2
# start_date              2
# end_date                2
# duration_(days)         2
# traveler_name           2
# traveler_age            2
# traveler_gender         2
# traveler_nationality    2
# accommodation_type      2
# accommodation_cost      2
# transportation_type     3
# transportation_cost     3
# dtype: int64

# %%
# Showing null values by rows

null_rows = file1[file1.isnull().any(axis=1)]
print(null_rows)
# Out:
#      trip_id  destination start_date   end_date  duration_(days)
# 71        72          NaN        NaN        NaN              NaN  \
# 82        83  Rome, Italy  4/15/2025  4/22/2025              7.0
# 127      128          NaN        NaN        NaN              NaN
#
#     traveler_name  traveler_age traveler_gender traveler_nationality
# 71            NaN           NaN             NaN                  NaN  \
# 82      James Kim          41.0            Male             American
# 127           NaN           NaN             NaN                  NaN
#
#     accommodation_type accommodation_cost transportation_type
# 71                 NaN                NaN                 NaN  \
# 82               Hotel                100                 NaN
# 127                NaN                NaN                 NaN
#
#     transportation_cost
# 71                  NaN
# 82                  NaN
# 127                 NaN

# %%
#Dropping null values as there are not many and it won't effect the outcome. 
file1 = file1.dropna()

# %%
# Displaying null values after dropping them. 
file1.isna().sum()
# Out:
# trip_id                 0
# destination             0
# start_date              0
# end_date                0
# duration_(days)         0
# traveler_name           0
# traveler_age            0
# traveler_gender         0
# traveler_nationality    0
# accommodation_type      0
# accommodation_cost      0
# transportation_type     0
# transportation_cost     0
# dtype: int64

# %%
#Checking Duplicates
duplicate = file1.duplicated()
duplicate.value_counts()
# Out:
# False    136
# Name: count, dtype: int64

# %%
file1.destination.value_counts()
# Out:
# destination
# Paris                          7
# Bali                           7
# Tokyo, Japan                   7
# Paris, France                  7
# Tokyo                          5
# Sydney                         5
# Rome                           5
# New York                       5
# Bali, Indonesia                5
# Rio de Janeiro, Brazil         4
# Bangkok                        4
# Cancun, Mexico                 4
# Barcelona, Spain               4
# London                         4
# Rome, Italy                    3
# Bangkok, Thailand              3
# Sydney, Aus                    3
# London, UK                     3
# New York, USA                  3
# Sydney, Australia              3
# Vancouver, Canada              2
# New York City, USA             2
# Barcelona                      2
# Cape Town                      2
# Dubai                          2
# Amsterdam, Netherlands         2
# Bangkok, Thai                  1
# Seoul, South Korea             1
# Los Angeles, USA               1
# Cape Town, SA                  1
# Phuket                         1
# Santorini                      1
# Seoul                          1
# Rio de Janeiro                 1
# Amsterdam                      1
# Cape Town, South Africa        1
# Athens, Greece                 1
# Phnom Penh                     1
# Sydney, AUS                    1
# Phuket, Thai                   1
# Australia                      1
# Canada                         1
# Spain                          1
# Dubai, United Arab Emirates    1
# Honolulu, Hawaii               1
# Berlin, Germany                1
# Marrakech, Morocco             1
# Edinburgh, Scotland            1
# Hawaii                         1
# Japan                          1
# Thailand                       1
# France                         1
# Phuket, Thailand               1
# Brazil                         1
# Greece                         1
# Egypt                          1
# Mexico                         1
# Italy                          1
# Auckland, New Zealand          1
# Name: count, dtype: int64

# %%
file1['destination'] = file1['destination'].replace({'Paris, France':'France',
                                                  'Bali, Indonesia':'Indonesia',
                                                  'Tokyo, Japan':'Japan',
                                                  'Rio de Janeiro, Brazil':'Brazil',
                                                  'Cancun, Mexico':'Mexico',
                                                  'Barcelona, Spain':'Spain',
                                                  'Bangkok, Thailand':'Thailand',
                                                  'Sydney, Aus':'Australia',
                                                  'London, UK':'UK',
                                                  'New York, USA':'USA',
                                                  'Sydney, Australia':'Australia',
                                                  'Vancouver, Canada':'Canada',
                                                  'New York City, USA':'USA',
                                                  'Amsterdam, Netherlands':'Netherlands',
                                                  'Bangkok, Thai':'Thailand',
                                                  'Seoul, South Korea':'South Korea',
                                                  'Los Angeles, USA':'USA',
                                                  'Cape Town, SA':'South Africa',
                                                  'Cape Town, South Africa':'South Africa',
                                                  'Athens, Greece':'Greece',
                                                  'Sydney, AUS':'Australia',
                                                  'Phuket, Thai':'Thailand',
                                                  'Dubai, United Arab Emirates':'United Arab Emirates',
                                                  'Honolulu, Hawaii':'USA',
                                                  'Berlin, Germany':'Germany',
                                                  'Marrakech, Morocco':'Morocco',
                                                  'Edinburgh, Scotland':'Scotland',
                                                  'Phuket, Thailand':'Thailand',
                                                  'Auckland, New Zealand':'New Zealand',
                                                  'Rome, Italy':'Italy'})
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_13636\944082579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file1['destination'] = file1['destination'].replace({'Paris, France':'France',

# %%
file1.destination.value_counts()
# Out:
# destination
# Japan                   8
# France                  8
# Australia               8
# Bali                    7
# USA                     7
# Paris                   7
# Thailand                7
# Sydney                  5
# Spain                   5
# Rome                    5
# Tokyo                   5
# Mexico                  5
# New York                5
# Brazil                  5
# Indonesia               5
# Bangkok                 4
# London                  4
# Italy                   4
# Canada                  3
# UK                      3
# Cape Town               2
# Dubai                   2
# Barcelona               2
# Greece                  2
# Netherlands             2
# South Africa            2
# Phnom Penh              1
# Santorini               1
# Phuket                  1
# Amsterdam               1
# Rio de Janeiro          1
# Seoul                   1
# Scotland                1
# Morocco                 1
# South Korea             1
# United Arab Emirates    1
# Egypt                   1
# Hawaii                  1
# Germany                 1
# New Zealand             1
# Name: count, dtype: int64

# %%
city_to_country = {'Paris': 'France',
                   'Bali': 'Indonesia',
                   'Tokyo': 'Japan',
                   'Rio de Janeiro': 'Brazil',
                   'Cancun': 'Mexico',
                   'Barcelona': 'Spain',
                   'Bangkok': 'Thailand',
                   'Sydney': 'Australia',
                   'London': 'UK',
                   'New York': 'USA',
                   'Vancouver': 'Canada',
                   'Amsterdam': 'Netherlands',
                   'Seoul': 'South Korea',
                   'Cape Town': 'South Africa',
                   'Athens': 'Greece',
                   'Phuket': 'Thailand',
                   'Dubai': 'United Arab Emirates',
                   'Honolulu': 'Hawaii',
                   'Berlin': 'Germany',
                   'Marrakech': 'Morocco',
                   'Edinburgh': 'Scotland',
                   'Auckland': 'New Zealand',
                   'Phnom Penh' : 'Cambodia',
                   'Santorini': 'Greece',
                   'Rome': 'Italy'}

file1['destination'] = file1['destination'].replace(city_to_country)
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_13636\2445505963.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file1['destination'] = file1['destination'].replace(city_to_country)

# %%
file1.destination.value_counts()
# Out:
# destination
# France                  15
# Japan                   13
# Australia               13
# Thailand                12
# Indonesia               12
# USA                     12
# Italy                    9
# UK                       7
# Spain                    7
# Brazil                   6
# Mexico                   5
# South Africa             4
# United Arab Emirates     3
# Canada                   3
# Netherlands              3
# Greece                   3
# South Korea              2
# Cambodia                 1
# Germany                  1
# Egypt                    1
# Hawaii                   1
# Scotland                 1
# Morocco                  1
# New Zealand              1
# Name: count, dtype: int64

# %%
#Now showing single variable for better understanding
#Single variables to know your dataset better

#DESTINATION 
sns.countplot(x=file1.destination)
plt.xticks(rotation=90)
plt.savefig("../Images/Destination.png", dpi=300)
plt.show()

#sns.barplot(data=file1, y='accommodation_type', x='traveler_age')
#plt.savefig("../Images/accommodation_type_by_gender.png", dpi=300)
#plt.show()

# %%
#Now showing single variable for better understanding
#Single variables to know your dataset better

#ACCOMMODATION TYPE
sns.countplot(x=file1.accommodation_type)
plt.xticks(rotation=90)
plt.savefig("../Images/Accommodation Type.png", dpi=300)
plt.show()

# %%
#Now showing single variable for better understanding
#Single variables to know your dataset better

#TRANSPORTATION TYPE 
sns.countplot(x=file1.transportation_type)
plt.xticks(rotation=90)
plt.savefig("../Images/Transportation_Type.png", dpi=300)
plt.show()

# %%
#Checking by using variables

sns.countplot(x=file1.destination, hue=file1.traveler_gender)
plt.xticks(rotation=90)
plt.savefig("../Images/destination_by_traveler_gender.png", dpi=300)
plt.show()

# %%
sns.countplot(x=file1.accommodation_type, hue=file1.traveler_gender)
plt.xticks(rotation=90)
plt.savefig("../Images/accommodation_type_by_traveler_gender.png", dpi=300)
plt.show()

#plt.xticks(rotation=90)
#plt.yticks(rotation=90)

# %%
sns.countplot(x=file1.transportation_type, hue=file1.traveler_gender)
plt.xticks(rotation=90)
plt.savefig("../Images/transportation_type_by_traveler_gender.png", dpi=300)
plt.show()

# %%
ax = sns.countplot(x=file1.accommodation_type, hue=file1.traveler_gender)
ax.bar_label(ax.containers[0])
plt.xticks(rotation=90)
plt.show()

# %%
file1.to_csv("../data/clean/travel_dataset.csv", index=False)
